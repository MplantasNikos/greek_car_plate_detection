# %%
import os 
import cv2
import matplotlib.pyplot as plt

# %%
path = "C:/Users/mplan/Desktop/my_stuff/greek_plate_recognition/YOLO/predicted_plates"
images = []

for image in os.listdir(path):
    image_n = path + '/' + image
    images.append(image_n)

# %%
images
# Out:
# ['C:/Users/mplan/Desktop/my_stuff/greek_plate_recognition/YOLO/predicted_plates/10_t.jpg',
#  'C:/Users/mplan/Desktop/my_stuff/greek_plate_recognition/YOLO/predicted_plates/11_t.jpg',
#  'C:/Users/mplan/Desktop/my_stuff/greek_plate_recognition/YOLO/predicted_plates/12_t.jpg',
#  'C:/Users/mplan/Desktop/my_stuff/greek_plate_recognition/YOLO/predicted_plates/13_t.jpg',
#  'C:/Users/mplan/Desktop/my_stuff/greek_plate_recognition/YOLO/predicted_plates/1_t.jpg',
#  'C:/Users/mplan/Desktop/my_stuff/greek_plate_recognition/YOLO/predicted_plates/2_t.jpg',
#  'C:/Users/mplan/Desktop/my_stuff/greek_plate_recognition/YOLO/predicted_plates/5_t.jpg',
#  'C:/Users/mplan/Desktop/my_stuff/greek_plate_recognition/YOLO/predicted_plates/6_t.jpg',
#  'C:/Users/mplan/Desktop/my_stuff/greek_plate_recognition/YOLO/predicted_plates/7_t.jpg',
#  'C:/Users/mplan/Desktop/my_stuff/greek_plate_recognition/YOLO/predicted_plates/9_t.jpg',
# ...

# %%
read = cv2.imread(images[3])

# %%
plt.figure(figsize=(5,5))
for i in range(10):
    plt.subplot(5,2,i+1)
    read_ = cv2.imread(images[i])
    plt.imshow(read_)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5,5))
for i in range(10):
    plt.subplot(5,2,i+1)
    read_ = cv2.imread(images[i])
    gray_ = cv2.cvtColor(read_,cv2.COLOR_RGB2GRAY)
    plt.imshow(gray_)
plt.tight_layout()
plt.show()
